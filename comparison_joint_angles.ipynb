# %%
from mvnx import MVNX
import pandas as pd
import openpyxl
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import plotly.graph_objects as go
import numpy as np

# %%
xsens = MVNX('../CHOLE_Robot_Joystick_M-001.mvnx')
joints_used = ['jL5S1','jL4L3','jL1T12','jT9T8','jT1C7','jC1Head','jRightT4Shoulder','jRightShoulder','jRightElbow','jRightWrist','jLeftT4Shoulder','jLeftShoulder','jLeftElbow','jLeftWrist']

# %%
vicon = pd.read_csv("../comprehensive_rula_vicon.csv")

# %%
vicon.head()
# Out:
#             Filename  ScoreA  ScoreB  GrandScore  UpperArmAngle  \
# 0  12_03_01_766.json       3       8           3        44.9226
# 1  12_03_01_783.json       4       8           4       114.1330
# 2  12_03_01_800.json       4       8           4         0.0000
# 3  12_03_01_816.json       4       8           4         0.0000
# 4  12_03_01_833.json       4       8           4         0.0000
#
#    LowerArmAngle  WristAngle  NeckAngle  NeckTwistAngle  TrunkAngle
# 0       61.79280          -1   124.3890        123.5160          -1
# 1        3.77756          -1    36.4548         52.4862          -1
# 2       91.74450          -1    53.5460         87.6967          -1
# 3       55.37180          -1    55.0766        123.5120          -1
# 4       52.31590          -1   126.4560        127.5160          -1

# %%
vicon['time'] = vicon.index + 1

# %%
x_means = []
y_means = []
z_means = []
labels = []



# Create a 3D scatter plot
fig = go.Figure(data=[go.Line(
    y = vicon.NeckTwistAngle,
    x = vicon.time,
)])

fig.show()
# Out:
# c:\Users\gu95gif\AppData\Local\miniconda3\envs\research\Lib\site-packages\plotly\graph_objs\_deprecations.py:378: DeprecationWarning: plotly.graph_objs.Line is deprecated.
# Please replace it with one of the following more specific types
#   - plotly.graph_objs.scatter.Line
#   - plotly.graph_objs.layout.shape.Line
#   - etc.
#
#   warnings.warn(

# %%
plt.hist(vicon.LowerArmAngle, bins=30, color='blue', alpha=0.7)
plt.title('Vicon Histogram')
plt.xlabel('Angle')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %%
plt.hist(vicon.TrunkAngle, bins=30, color='blue', alpha=0.7)
plt.title('Vicon Histogram')
plt.xlabel('Angle')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %%
# these might be the head angles
xsens.jointAngle[:][15:18]
# how can I compare them to the Vidon Rula Angles?
# Out:
# array([[-3.78824500e+00, -2.18749000e+00, -1.21917300e+00,
#         -1.76888100e+00, -8.06194000e-01, -6.38768300e+00,
#         -1.76896500e+00, -8.06012000e-01, -5.67253000e-01,
#         -1.25753600e+00, -7.37704000e-01,  5.41002600e+00,
#          1.40662900e+00,  3.95577900e+00,  2.71830920e+01,
#          3.38251600e+00,  6.97163800e+00,  1.45989340e+01,
#         -6.21572000e+00, -1.73922400e+00,  3.97817500e+00,
#          1.19114050e+01,  3.10297100e+01,  1.06833240e+01,
#          5.71318900e+00,  1.18548491e+02,  1.31631985e+02,
#         -1.44344700e+01, -1.50413460e+01, -3.32048100e+00,
#         -8.13077800e+00,  1.80926300e+00, -2.92280000e-02,
#         -3.46715540e+01, -1.62549570e+01, -1.26148660e+01,
#         -3.90986600e+00,  1.41995015e+02,  7.63059240e+01,
#         -7.11022700e+00, -2.62361900e+00, -2.23826840e+01,
#         -0.00000000e+00,  0.00000000e+00, -0.00000000e+00,
#         -0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
# ...

# %%
plt.hist(xsens.LowerArmAngle, bins=30, color='blue', alpha=0.7)
plt.title('XSense Histogram')
plt.xlabel('Angle')
plt.ylabel('Frequency')
plt.grid(axis='y', alpha=0.75)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 plt.hist(xsens.LowerArmAngle, bins=30, color='blue', alpha=0.7)
#       2 plt.title('XSense Histogram')
#       3 plt.xlabel('Angle')
#
# AttributeError: 'MVNX' object has no attribute 'LowerArmAngle'
